# %%
using PyPlot
using ODE
# Out:
# ┌ Info: Recompiling stale cache file /Users/wfarr/.julia/compiled/v1.2/ODE/GIz9k.ji for ODE [968af70c-4668-4518-a492-221ac4f6bdfa]
# └ @ Base loading.jl:1240

# %%
function euler_step(x0, y0, f, h)
    return y0 .+ h.*f(x0, y0)
end
# Out:
# euler_step (generic function with 2 methods)

# %%
xs = collect(0:0.01:3)
ys = exp.(-xs)
plot(xs, ys)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13b131748>

# %% [markdown]
# $y = \exp(-x)$ satisfies
# $$
# \frac{dy}{dx} = -y
# $$
# with $y(0) = 1$.

# %%
function f_exp(x, y)
    println("Called at x = $(x)")
    return -y
end
# Out:
# f_exp (generic function with 1 method)

# %%
function euler_solve(x0, y0, f, x1, h)
    x = x0
    y = y0
    
    xs = [x0]
    ys = [y0]
    while x < x1
        y = euler_step(x, y, f, h)
        x = x+h
        push!(xs, x)
        push!(ys, y)
    end
    
    xs, ys
end
# Out:
# euler_solve (generic function with 1 method)

# %%
xs, ys = euler_solve(0.0, [1.0], f_exp, 10.0, 2.1)
# Out:
# ([0.0, 2.1, 4.2, 6.300000000000001, 8.4, 10.5], Array{Float64,1}[[1.0], [-1.1], [1.2100000000000004], [-1.3310000000000004], [1.4641000000000006], [-1.610510000000001]])

# %%
plot(xs, [y[1] for y in ys])
plot(xs, exp.(-xs))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13c14cf60>

# %%
xs = collect(0:0.1:10)
ys = [[1.0]]
for x in xs[2:end]
    y = evolve_ode(Midpoint, f_exp, x-0.1, ys[end], x, atol=1e-3)
    push!(ys, y)
end
# Out:
# Called at x = 0.0
# Called at x = 0.0005
# Called at x = 0.001
# Called at x = 0.002
# Called at x = 0.003
# Called at x = 0.005
# Called at x = 0.007
# Called at x = 0.011
# Called at x = 0.015
# Called at x = 0.023
# Called at x = 0.031
# Called at x = 0.04695363036235364
# Called at x = 0.06290726072470729
# Called at x = 0.08145363036235365
# Called at x = 0.1
# Called at x = 0.1005
# Called at x = 0.101
# Called at x = 0.10200000000000001
# Called at x = 0.10300000000000001
# Called at x = 0.10500000000000001
# Called at x = 0.10700000000000001
# Called at x = 0.11100000000000002
# Called at x = 0.11500000000000002
# Called at x = 0.12300000000000003
# Called at x = 0.131
# Called at x = 0.14700000000000002
# Called at x = 0.163
# Called at x = 0.1815
# Called at x = 0.19999999999999998
# Called at x = 0.20049999999999998
# Called at x = 0.20099999999999998
# Called at x = 0.20199999999999999
# Called at x = 0.20299999999999999
# Called at x = 0.205
# Called at x = 0.207
# ...

# %%
plot(xs, [y[1] for y in ys])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x130dd3320>
